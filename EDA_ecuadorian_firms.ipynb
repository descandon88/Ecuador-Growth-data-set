# %% [markdown]
# <a href="https://colab.research.google.com/github/descandon88/tesis_maestria/blob/main/EDA_ecuadorian_firms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
import os
import pandas as pd
import numpy as np
# Librerías para visualizacion
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm
import re
import networkx as nx
from itertools import count
from itertools import combinations
from itertools import product
import statsmodels.api as sm
import urllib.request, json
# !pip3 install geopandas
import geopandas
# -- set scientific notation to display numbers fully rather than exponential
pd.set_option('display.float_format', '{:.2f}'.format)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all' 
import seaborn as sns
sns.set_style('whitegrid') # grids en dark background

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 100000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth',300)
print('librerías cargadas')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 28.9 MB/s eta 0:00:00
# ...
# librerías cargadas

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
## Se importa la base de firmas del Ecuador drive
df_base = pd.read_csv("/content/drive/MyDrive/eci//base/base_firms/EMPRESAS_periodo_2012_2021.csv", encoding='utf-8')

# %%
df_base.head()
df_base.info()
# Out:
#     id_empresa  anio situacion                             forma_institucional unidad_legal_tipo clase_contribuyente obligado_llevar_contabilidad gsectores codigo_seccion                                          seccion codigo_division                                                                    division codigo_clase                                                                            clase                             zona_planif  codigo_provincia provincia  codigo_canton      canton ventas_totales ventas_nacionales exportaciones_netas         plazas_equiv plazas_equiv_hombres plazas_equiv_mujeres plazas plazas_hombres plazas_mujeres plazas_ult plazas_ult_hombres plazas_ult_mujeres plazas_iess_trim_1   plazas_iess_trim_2   plazas_iess_trim_3 plazas_iess_trim_4 plazas_rango_edad_1  plazas_rango_edad_2 plazas_rango_edad_3 plazas_rango_edad_4 plazas_rango_edad_5 plazas_ult_rango_edad_1 plazas_ult_rango_edad_2 plazas_ult_rango_edad_3 plazas_ult_rango_edad_4 plazas_ult_rango_e
# ...

# %%
# df_act = df_base[(df_base['forma_institucional']="Sociedad con fines de lucro")&(df_base['forma_institucional']="Sociedad con fines de lucro")].copy()
opcion_form_institucional=["Sociedad con fines de lucro"]
opcion_gsectores=['Industria Manufacturera', 'Servicios']
opcion_situacion=['Activo']
df_filt=df_base.loc[df_base['forma_institucional'].isin(opcion_form_institucional)].copy()
df_filt=df_filt.loc[df_filt['gsectores'].isin(opcion_gsectores)].copy()

df_filt=df_filt.loc[df_filt['situacion'].isin(opcion_situacion)].copy()
# df_filt['plazas'] = df_filt.plazas.astype(int)
# df_filt['plazas'] = df_filt['plazas'].astype('int')
# df_filt=df_filt.loc[df_filt['plazas']>15].copy()
df_filt.drop(columns=['empleo_hombres', 'empleo_mujeres','plazas_rango_edad_1','plazas_hombres','plazas_equiv','obligado_llevar_contabilidad','remuneraciones','remuneraciones_hombres',
                      'remuneraciones_mujeres','plazas_mujeres','plazas_equiv_hombres','plazas_equiv_mujeres',	'plazas_ult',	'plazas_ult_hombres',	'plazas_ult_mujeres',	'plazas_iess_trim_1',	'plazas_iess_trim_2',	'plazas_iess_trim_3',
                      'plazas_iess_trim_4',	'plazas_rango_edad_2'	,'plazas_rango_edad_3',	'plazas_rango_edad_4'	,'plazas_rango_edad_5',	'plazas_ult_rango_edad_1'	,'plazas_ult_rango_edad_2',	'plazas_ult_rango_edad_3',
                      'plazas_ult_rango_edad_4',	'plazas_ult_rango_edad_5',	'empleo_equiv',	'empleo_equiv_hombres',	'empleo_equiv_mujeres',	'empleo',	'empleo_ult',	'empleo_ult_hombres',	'empleo_ult_mujeres',
                      'empleo_iess_trim_1',	'empleo_iess_trim_2'	,'empleo_iess_trim_3',	'empleo_iess_trim_4',	'empleo_rango_edad_1',	'empleo_rango_edad_2',	'empleo_rango_edad_3'	,'empleo_rango_edad_4',	'empleo_rango_edad_5',
                      'empleo_ult_rango_edad_1'	,'empleo_ult_rango_edad_2',	'empleo_ult_rango_edad_3','zona_planif',	'empleo_ult_rango_edad_4'	,'empleo_ult_rango_edad_5','fecha_inicio_actividad','propietarios_sexo',
                      'estrato_plazase'	,'estrato_empleoe'	,'estrato_plazasp'	,'estrato_empleop',	'estrato_plazasu'	,'estrato_empleou'], axis=1,inplace=True)

df_filt.sample(n=5) 
df_filt.info()
## mayores a 50000 
# new_column_list
# Out:
#          id_empresa  anio situacion          forma_institucional unidad_legal_tipo clase_contribuyente  gsectores codigo_seccion                                                        seccion codigo_division                                      division codigo_clase                                                                  clase  codigo_provincia  provincia  codigo_canton     canton ventas_totales ventas_nacionales exportaciones_netas plazas                       estrato_ventas                   estrato_ventas_cop    estrato_plazas_cop       tamanoe_plazas       tamanoe_empleo       tamanop_empleo       tamanou_empleo       tamanop_plazas       tamanou_plazas       tamano_cop rise                                             estructura_estrat fecha_cese_actividad fecha_reinicio_actividad  fecha_inscripcion fecha_actualizacion fecha_suspension_definitiva
# ...
